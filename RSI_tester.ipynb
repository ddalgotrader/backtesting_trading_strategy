# %%
import pandas as pd
from Strategies import *
from StrategyTester import StrategyTester as tester_st

# %%
df=pd.read_csv('oanda_EURUSD_1_year.csv', parse_dates=['Date'], index_col='Date')

# %%
tester=tester_st(data=df, symbol='EURUSD', strategy_func=rsi)

# %%
tester.test_strategy(freq=30, window=14,down_level=30, up_level=70, neutral_level_dist=20, bars_ob=1)
# Out:
#                buy_and_hold  rsi_startegy
# simple_return       1.04458       1.00910
# mean_return         0.04410       0.00916
# stddev              0.10768       0.06134
# sharpe_ratio        0.40953       0.14933
# sortino_ratio       0.58553       0.21865
# max_dd              0.11561       0.04854
# cagr                0.04509       0.00920
# calmar_ratio        0.39000       0.18959
# kelly               0.02342       0.80292

# %%
tester.plot_results()
# Out:
# <div>                            <div id="9c010ae7-b0d8-48c1-80f2-75ca60b7ab3e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9c010ae7-b0d8-48c1-80f2-75ca60b7ab3e")) {                    Plotly.newPlot(                        "9c010ae7-b0d8-48c1-80f2-75ca60b7ab3e",                        [{"mode":"lines","name":"buy and hold","x":["2022-05-02T00:00:00","2022-05-02T00:30:00","2022-05-02T01:00:00","2022-05-02T01:30:00","2022-05-02T02:00:00","2022-05-02T02:30:00","2022-05-02T03:00:00","2022-05-02T03:30:00","2022-05-02T04:00:00","2022-05-02T04:30:00","2022-05-02T05:00:00","2022-05-02T05:30:00","2022-05-02T06:00:00","2022-05-02T06:30:00","2022-05-02T07:00:00","2022-05-02T07:30:00","2022-05-02T08:00:00","2022-05-02T08:30:00","2022-05-02T09:00:00","2022-
# ...

# %%
tester.data
# Out:
#                         Open     High      Low    Close  vol    spread  pips
# Date
# 2022-05-02 00:00:00  1.05349  1.05402  1.05348  1.05394  291  0.000100  1.00
# 2022-05-02 00:01:00  1.05393  1.05401  1.05390  1.05398  203  0.000100  1.00
# 2022-05-02 00:02:00  1.05399  1.05410  1.05391  1.05404  170  0.000100  1.00
# 2022-05-02 00:03:00  1.05406  1.05450  1.05406  1.05443  163  0.000100  1.00
# 2022-05-02 00:04:00  1.05443  1.05448  1.05431  1.05436  106  0.000100  1.00
# ...                      ...      ...      ...      ...  ...       ...   ...
# 2023-04-28 20:54:00  1.10174  1.10174  1.10168  1.10168   19  0.000095  0.95
# 2023-04-28 20:55:00  1.10168  1.10176  1.10166  1.10172   67  0.000095  0.95
# 2023-04-28 20:56:00  1.10174  1.10176  1.10166  1.10168   44  0.000095  0.95
# 2023-04-28 20:57:00  1.10168  1.10172  1.10164  1.10170   33  0.000095  0.95
# 2023-04-28 20:58:00  1.10170  1.10170  1.10170  1.10170    2  0.000095  0.95
#
# [361489 rows x 7 columns]

# %%
tester.plot_trades(start='2022-06-20', end='2022-08-20')
# Out:
# <div>                            <div id="ba689078-41cd-400e-8ebc-c9f53abd4c82" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba689078-41cd-400e-8ebc-c9f53abd4c82")) {                    Plotly.newPlot(                        "ba689078-41cd-400e-8ebc-c9f53abd4c82",                        [{"close":[1.0492,1.04934,1.04969,1.04934,1.05024,1.05184,1.05194,1.05284,1.0529,1.0523,1.05242,1.05292,1.05288,1.05246,1.05226,1.0517,1.05158,1.05246,1.05422,1.05328,1.05282,1.0532,1.05256,1.05262,1.052,1.05172,1.05194,1.05186,1.0532,1.0535,1.05293,1.0538,1.0525,1.05234,1.05116,1.0506,1.05044,1.04992,1.05036,1.05114,1.05094,1.05112,1.05116,1.05116,1.05104,1.05184,1.05175,1.05175,1.05273,1.05328,1.05344,1.05341,1.05336,1.05335,1.05288,1.05323,1.05269,1.05224,1.051
# ...
