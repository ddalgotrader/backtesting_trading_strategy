# %%
import pandas as pd
from Strategies import *
from StrategyTester import StrategyTester as tester_st

# %%
df=pd.read_csv('oanda_EURUSD_1_year.csv', parse_dates=['Date'],
               index_col='Date')

# %%
tester=tester_st(data=df, symbol='EURUSD', strategy_func=rsi)

# %%
tester.test_strategy(freq=30, window=14,down_level=30, up_level=70, 
                     neutral_level_dist=None, bars_ob=3)
# Out:
#                buy_and_hold  rsi_startegy
# simple_return       1.04458       1.22588
# mean_return         0.04410       0.20592
# stddev              0.10768       0.10671
# sharpe_ratio        0.40953       1.92976
# sortino_ratio       0.58553       2.83502
# max_dd              0.11561       0.06509
# cagr                0.04509       0.22865
# calmar_ratio        0.39000       3.51308
# kelly               0.02342       0.07385

# %%
tester.plot_results()
# Out:
# <div>                            <div id="1aacd831-e370-4430-8253-a2a533d0a5cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1aacd831-e370-4430-8253-a2a533d0a5cd")) {                    Plotly.newPlot(                        "1aacd831-e370-4430-8253-a2a533d0a5cd",                        [{"mode":"lines","name":"buy and hold","x":["2022-05-02T00:00:00","2022-05-02T00:30:00","2022-05-02T01:00:00","2022-05-02T01:30:00","2022-05-02T02:00:00","2022-05-02T02:30:00","2022-05-02T03:00:00","2022-05-02T03:30:00","2022-05-02T04:00:00","2022-05-02T04:30:00","2022-05-02T05:00:00","2022-05-02T05:30:00","2022-05-02T06:00:00","2022-05-02T06:30:00","2022-05-02T07:00:00","2022-05-02T07:30:00","2022-05-02T08:00:00","2022-05-02T08:30:00","2022-05-02T09:00:00","2022-
# ...

# %%
tester.plot_trades(start='2023-02-06', end='2023-03-06')
# Out:
# <div>                            <div id="a14d5f1b-1794-4db6-bb08-3faaddf3a993" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a14d5f1b-1794-4db6-bb08-3faaddf3a993")) {                    Plotly.newPlot(                        "a14d5f1b-1794-4db6-bb08-3faaddf3a993",                        [{"close":[1.07864,1.07888,1.07896,1.07851,1.0789,1.07908,1.07944,1.07902,1.07966,1.07964,1.07931,1.07967,1.07915,1.07873,1.07904,1.078,1.07756,1.07852,1.07723,1.07665,1.07699,1.07658,1.07612,1.07662,1.07722,1.07732,1.0771,1.07581,1.07534,1.07447,1.07314,1.07302,1.07346,1.07212,1.0718,1.07132,1.0717,1.07264,1.07352,1.07247,1.07277,1.07298,1.07264,1.0725,1.07275,1.07276,1.07254,1.07292,1.07316,1.07363,1.07373,1.07412,1.07403,1.0741,1.07404,1.07382,1.07344,1.07331,1
# ...
